# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import evidently as ev
import joblib

# %%
artifact_path = "/Users/phil/philclarkphd/sleep/model_artifacts/XGBoost_1.0/XGBoost_1.0_artifacts.pkl"

model, metadata, encoder = joblib.load(artifact_path)

# %%
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
metadata
# Out:
# {'model_name': 'XGBoost_1.0',
#  'model_version': '1.0',
#  'current_path': datetime.datetime(2024, 5, 7, 10, 41, 15, 722950),
#  'feature_path': '/Users/phil/philclarkphd/sleep/sleep_data/df_features_041924.csv',
#  'feature_cols': ['EEG_std',
#   'EEG_ss',
#   'EEG_amp',
#   'EMG_std',
#   'EMG_ss',
#   'EMG_events',
#   'delta_rel',
#   'theta_rel',
#   'theta_over_delta'],
#  'target_col': 'score',
#  'group_col': 'ID_day',
#  'time_series_idx': 'epoch',
#  'train_size': 0.8,
#  'n_train_rows': 197738,
#  'n_test_rows': 49446,
#  'search_space': {'n_estimators': [100, 200, 300],
#   'max_depth': [3, 5, 7],
#   'learning_rate': [0.1, 0.01, 0.001],
#   'subsample': [0.6, 0.8, 1.0],
#   'colsample_bytree': [0.6, 0.8, 1.0],
#   'gamma': [0, 0.1, 0.2],
#   'reg_alpha': [0, 0.01, 0.1],
#   'reg_lambda': [0, 0.01, 0.1]},
#  'random_state': 42,
#  'cv_folds': 5,
#  'n_iter': 10,
#  'eval_metric': 'f1_weighted',
#  'best_params': {'subsample': 0.8,
#   'reg_lambda': 0,
# ...
